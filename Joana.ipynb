# %%
import pandas as pd

# %%
motorcycle = pd.read_csv("C:\\Users\\jonie\\Documents\\jupyter\\motor_data.csv")

# %%
motorcycle
# Out:
#    Top Selling Motorcycle in the Philippines    Motorcycle Model  \
# 0                                          1         Yamaha Nmax
# 1                                          2        Yamaha Aerox
# 2                                          3     Honda Click125i
# 3                                          4          Honda Beat
# 4                                          5           Honda ADV
# 5                                          6     Yamaha Mio i125
# 6                                          7     Honda Click150i
# 7                                          8  Yamaha Mio Sporty
# 8                                          9  Suzuki Raider R150
# 9                                         10  Kawasaki Ninja 400
#
#    Date of Release    Price  Specs Total Sold  Reviews
# 0             2019  134,500  155cc     40,000   7,500
# 1             2017  122,900  155cc     30,000   6,500
# 2             2018   76,900  125cc     30,500   5,500
# ...

# %%
import matplotlib.pyplot as plt

import numpy as np

# %%
model = ['Yamaha Nmax', 'Yamaha Aerox', 'Honda Click125i', 'Honda Beat', 'Honda ADV', 'Yamaha Mioi125', 'Honda Click150i', 'Yamaha Mio Sporty ',  ' Suzuki Raider R150', ' Kawasaki Ninja400']
price = [134500, 122900, 76900, 66900, 149000, 75900, 98900, 67900, 97900,31500]
totalsold = [40000, 30000, 30500, 20500, 20000, 30000, 30500, 40000, 20000, 6000]
reviews = [7500, 6500, 5500, 4700, 3800, 6900, 4850, 5100, 4800, 3700]


h=0.4
bar1 = np.arange(len(model))
bar2 = [i+0.4 for i in bar1]
bar3 = [i+0.4 for i in bar2]
plt.rc('figure', figsize=(25,10))

plt.bar(bar1,price, 0.4, label="price", color="green")
plt.bar(bar2,totalsold, 0.4, label="total sold", color="orange")
plt.bar(bar3,reviews, 0.4, label="reviews", color="blue")


plt.title("Top Selling Motorcycle in the Philippines", fontsize="38", color="maroon")
plt.xlabel("Motorcycle Model (Total Sold and Reviews)", fontsize="22", color="blue")
plt.ylabel("Motorcycle Price", fontsize="22", color="red")


plt.xticks(bar1,model, size="13")
#plt.legend location string
plt.legend(loc="best", shadow=True, fontsize="xx-large")
plt.grid()
plt.show()
